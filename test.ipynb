# %%
import pandas as pd

# %%
x=pd.DataFrame([0,3,2,3,4,50,6,7,8,9], columns=['lol'])
print(x>5)
# Out:
#      lol
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
# 5   True
# 6   True
# 7   True
# 8   True
# 9   True
